# %% [markdown]
# Import and prepare 2017 Washington, DC crime data

# %%
import pandas as pd
link_crime = 'https://github.com/qziegler/data/raw/master/raw/FY2017_DCCrimeData.csv'
dc_crime = pd.read_csv(link_crime, header=0)

assert len(dc_crime) == 33070
assert len(dc_crime.columns) == 18

dc_crime.columns = map(str.lower, dc_crime.columns)

dc_crime['tract'] = dc_crime['census_tract'].astype('float64')
dc_crime.dtypes

assert dc_crime['tract'].isnull().sum() == 83

# %% [markdown]
# Import and prepare race/ethnicity data from the 2016 American Community Survey, 5-Year Estimates

# %%
link_race = 'https://github.com/qziegler/data/raw/master/raw/ACS_16_5YR_B03002/ACS_16_5YR_B03002_with_ann.csv'
census_race = pd.read_csv(link_race, header=0)

assert len(census_race) == 180
assert len(census_race.columns) == 45

census_race = census_race.drop(census_race.index[0])
census_race.rename(index=str, columns={'GEO.id':'geo_id',
                                        'GEO.id2':'geo_id2',
                                        'HD01_VD01':'total_pop',
                                        'HD01_VD03':'total_nhw',
                                        'HD01_VD04':'total_black',
                                        'HD01_VD05':'total_aian',
                                        'HD01_VD06':'total_asian',
                                        'HD01_VD07':'total_api',
                                        'HD01_VD08':'total_other',
                                        'HD01_VD09':'total_multi',
                                        'HD01_VD12':'total_hisp'}, inplace = True)

#Census variables to keep for analysis
vars = ['geo_id', 'geo_id2', 'total_pop', 'total_nhw', 'total_black', 'total_aian',
        'total_asian', 'total_api', 'total_other', 'total_multi', 'total_hisp']

census_race.dtypes
# Out:
# geo_id               object
# geo_id2              object
# GEO.display-label    object
# total_pop            object
# HD02_VD01            object
# HD01_VD02            object
# HD02_VD02            object
# total_nhw            object
# HD02_VD03            object
# total_black          object
# HD02_VD04            object
# total_aian           object
# HD02_VD05            object
# total_asian          object
# HD02_VD06            object
# total_api            object
# HD02_VD07            object
# total_other          object
# HD02_VD08            object
# total_multi          object
# HD02_VD09            object
# HD01_VD10            object
# HD02_VD10            object
# HD01_VD11            object
# HD02_VD11            object
# total_hisp           object
# HD02_VD12            object
# HD01_VD13            object
# HD02_VD13            object
# HD01_VD14            object
# HD02_VD14            object
# HD01_VD15            object
# HD02_VD15            object
# HD01_VD16            object
# HD02_VD16            object
# HD01_VD17            object
# HD02_VD17            object
# HD01_VD18            object
# HD02_VD18            object
# HD01_VD19            object
# HD02_VD19            object
# HD01_VD20            object
# HD02_VD20            object
# HD01_VD21            object
# HD02_VD21            object
# dtype: object

# %% [markdown]
# Confirm race/ethnicity categories sum to 1

# %%
census_race['summer'] = 0
for var in vars:
    if (var != 'geo_id') & (var != 'geo_id2') & (var != 'total_pop'):
        census_race[var] = census_race[var].astype('int64')
        census_race['summer'] = census_race['summer'] + census_race[var]

census_race['total_pop'] = census_race['total_pop'].astype('int64')

# %%
import numpy as np
np.all(census_race['summer'] == census_race['total_pop'])
# Out:
# True

# %%
del census_race['summer']

# %% [markdown]
# Create tract-level shares for each race/ethnicity category

# %%
census_race = census_race[vars]

races = ['nhw', 'black', 'aian', 'asian', 'api', 'other', 'multi', 'hisp']

for re in races:
    census_race['share' + re] = census_race['total_' + re]/census_race['total_pop']

# %% [markdown]
# Prepare census race data for merging with crime data and merge

# %%
census_race['tract'] = census_race.geo_id2.str[6:]
census_race['tract'] = census_race['tract'].astype('float64')

data = pd.merge(dc_crime, census_race, on='tract', validate='m:1', indicator=True, how='left')
data['_merge'].value_counts()
# Out:
# both          32987
# left_only        83
# right_only        0
# Name: _merge, dtype: int64

# %%
bad_tracts = {'tracts': data.tract[data._merge=="left_only"]}
bad_tracts_df = pd.DataFrame.from_dict(bad_tracts)
assert bad_tracts_df['tracts'].isnull().sum() == 83
del data['_merge']

# %% [markdown]
# Import and prepare median household income data from the 2016 American Community Survey, 5-Year Estimates

# %%
link_income = 'https://github.com/qziegler/data/raw/master/raw/ACS_16_5YR_S1903/ACS_16_5YR_S1903_with_ann.csv'
census_income = pd.read_csv(link_income, header=0)

assert len(census_income) == 180
assert len(census_income.columns) == 123

census_income = census_income.drop(census_income.index[0])
census_income.rename(index=str, columns={'GEO.id':'geo_id',
                                        'GEO.id2':'geo_id2',
                                        'HC02_EST_VC02':'hh_med_income',
                                        }, inplace = True)

vars = ['geo_id', 'geo_id2', 'hh_med_income']

census_income = census_income[vars]

census_income['tract'] = census_income.geo_id2.str[6:]
census_income['tract'] = census_income['tract'].astype('float64')
del census_income['geo_id']
del census_income['geo_id2']

N = len(census_income)-1
for i in range(0,N):
    try:
        float(census_income.hh_med_income[i])
    except ValueError:
        print(str('invalid float type ') + census_income.hh_med_income[i])
        
census_income['hh_med_income'].replace('-','0',inplace=True)
census_income['hh_med_income'] = census_income['hh_med_income'].astype('float64')
# Out:
# invalid float type -
# invalid float type -
# invalid float type -

# %% [markdown]
# Merge on census income data to main data frame

# %%
data = pd.merge(data, census_income, on='tract', validate='m:1', indicator=True, how='left')
data['_merge'].value_counts()
# Out:
# both          32987
# left_only        83
# right_only        0
# Name: _merge, dtype: int64

# %%
bad_tracts = {'tracts': data.tract[data._merge=="left_only"]}
bad_tracts_df = pd.DataFrame.from_dict(bad_tracts)
assert bad_tracts_df['tracts'].isnull().sum() == 83
del data['_merge']

# %% [markdown]
# Import and prepare unemployment rate for individuals 16 years of age and older from the 2016 American Community Survey, 5-Year Estimates

# %%
link_employment = 'https://github.com/qziegler/data/raw/master/raw/ACS_16_5YR_S2301/ACS_16_5YR_S2301_with_ann.csv'
census_employment = pd.read_csv(link_employment, header=0)

assert len(census_employment) == 180
assert len(census_employment.columns) == 283

census_employment = census_employment.drop(census_employment.index[0])
census_employment.rename(index=str, columns={'GEO.id':'geo_id',
                                             'GEO.id2':'geo_id2',
                                             'HC04_EST_VC01':'unemp_rate',
                                             }, inplace = True)

vars = ['geo_id', 'geo_id2', 'unemp_rate']

census_employment = census_employment[vars]

census_employment['tract'] = census_employment.geo_id2.str[6:]
census_employment['tract'] = census_employment['tract'].astype('float64')
del census_employment['geo_id']
del census_employment['geo_id2']

N = len(census_employment)-1
for i in range(0,N):
    try:
        float(census_employment.unemp_rate[i])
    except ValueError:
        print(str('invalid float type ') + census_employment.unemp_rate[i])

census_employment['unemp_rate'] = census_employment['unemp_rate'].astype('float64')
census_employment['unemp_rate'] = census_employment['unemp_rate']/100

# %% [markdown]
# Merge on census unemployment data to main data frame

# %%
data = pd.merge(data, census_employment, on='tract', validate='m:1', indicator=True, how='left')
data['_merge'].value_counts()
# Out:
# both          32987
# left_only        83
# right_only        0
# Name: _merge, dtype: int64

# %%
bad_tracts = {'tracts': data.tract[data._merge=="left_only"]}
bad_tracts_df = pd.DataFrame.from_dict(bad_tracts)
assert bad_tracts_df['tracts'].isnull().sum() == 83
del data['_merge']

# %% [markdown]
# Import and prepare occupancy status data from the 2016 American Community Survey, 5-Year Estimates

# %%
link_occupancy = 'https://github.com/qziegler/data/raw/master/raw/ACS_16_5YR_B25002/ACS_16_5YR_B25002_with_ann.csv'
census_occupancy = pd.read_csv(link_occupancy, header=0)

assert len(census_occupancy) == 180
assert len(census_occupancy.columns) == 9

census_occupancy = census_occupancy.drop(census_occupancy.index[0])
census_occupancy.rename(index=str, columns={'GEO.id':'geo_id',
                                            'GEO.id2':'geo_id2',
                                            'HD01_VD01':'total_units',
                                            'HD01_VD02':'total_occupied',
                                            'HD01_VD03':'total_vacant',
                                             }, inplace = True)

vars = ['geo_id', 'geo_id2', 'total_units', 'total_occupied', 'total_vacant']

census_occupancy = census_occupancy[vars]

census_occupancy['tract'] = census_occupancy.geo_id2.str[6:]
census_occupancy['tract'] = census_occupancy['tract'].astype('float64')
del census_occupancy['geo_id']
del census_occupancy['geo_id2']

N = len(census_occupancy)-1
for i in range(0,N):
    for var in 'total_units', 'total_occupied', 'total_vacant':
        try:
            float(census_occupancy[var].iloc[i])
        except ValueError:
            print(str('invalid float type ') + census_occupancy[var].iloc[i])

for var in 'total_units', 'total_occupied', 'total_vacant':
    census_occupancy[var] = census_occupancy[var].astype('float64')
    
census_occupancy['vacancy_rate'] = census_occupancy['total_vacant']/census_occupancy['total_units']

census_occupancy = census_occupancy[['tract', 'vacancy_rate']]

# %% [markdown]
# Merge on census vacancy rate data

# %%
data = pd.merge(data, census_occupancy, on='tract', validate='m:1', indicator=True, how='left')
data['_merge'].value_counts()
# Out:
# both          32987
# left_only        83
# right_only        0
# Name: _merge, dtype: int64

# %%
bad_tracts = {'tracts': data.tract[data._merge=="left_only"]}
bad_tracts_df = pd.DataFrame.from_dict(bad_tracts)
assert bad_tracts_df['tracts'].isnull().sum() == 83
del data['_merge']

# %% [raw]
# Review and set data types

# %%
print(data.dtypes)

cat_vars = ['offense', 'method']
for var in cat_vars:
    data[var] = data[var].astype('category')
    
data['hh_med_income'].replace(0,np.nan,inplace=True)

display(data)
# Out:
# report_dat               object
# shift                    object
# offense                  object
# method                   object
# block                    object
# district                float64
# psa                     float64
# ward                      int64
# anc                      object
# neighborhood_cluster     object
# block_group              object
# census_tract            float64
# voting_precinct          object
# ccn                       int64
# xblock                  float64
# yblock                  float64
# start_date               object
# end_date                 object
# tract                   float64
# geo_id                   object
# geo_id2                  object
# total_pop               float64
# total_nhw               float64
# total_black             float64
# total_aian              float64
# total_asian             float64
# total_api               float64
# total_other             float64
# total_multi             float64
# total_hisp              float64
# sharenhw                float64
# shareblack              float64
# shareaian               float64
# shareasian              float64
# shareapi                float64
# shareother              float64
# sharemulti              float64
# sharehisp               float64
# hh_med_income           float64
# unemp_rate              float64
# vacancy_rate            float64
# dtype: object
#            report_dat     shift                     offense  method  \
# 0        2/6/17 20:11   EVENING                 THEFT/OTHER  OTHERS
# 1        6/3/17 12:54       DAY                THEFT F/AUTO  OTHERS
# 2         4/7/17 0:00  MIDNIGHT                    HOMICIDE  OTHERS
# 3        3/13/17 0:00  MIDNIGHT                    HOMICIDE  OTHERS
# 4         1/8/17 0:00  MIDNIGHT                    HOMICIDE  OTHERS
# 5       1/25/17 12:51       DAY                THEFT F/AUTO  OTHERS
# 6         1/1/17 7:57       DAY                 THEFT/OTHER  OTHERS
# 7         1/1/17 8:38       DAY                 THEFT/OTHER  OTHERS
# 8        1/1/17 20:16   EVENING                 THEFT/OTHER  OTHERS
# 9         1/1/17 1:56  MIDNIGHT  ASSAULT W/DANGEROUS WEAPON     GUN
# 10       1/4/17 12:56       DAY         MOTOR VEHICLE THEFT  OTHERS
# 11      1/16/17 19:51   EVENING         MOTOR VEHICLE THEFT  OTHERS
# 12       1/1/17 12:04       DAY                     ROBBERY  OTHERS
# 13       1/1/17 11:48       DAY                 THEFT/OTHER  OTHERS
# 14       1/1/17 13:19       DAY                THEFT F/AUTO  OTHERS
# 15       1/1/17 12:27       DAY                 THEFT/OTHER  OTHERS
# 16       1/1/17 12:33       DAY                THEFT F/AUTO  OTHERS
# 17       1/1/17 13:01       DAY                THEFT F/AUTO  OTHERS
# 18       1/1/17 13:32       DAY                THEFT F/AUTO  OTHERS
# 19       1/1/17 14:33       DAY                THEFT F/AUTO  OTHERS
# 20       1/4/17 10:16       DAY                THEFT F/AUTO  OTHERS
# 21       1/1/17 14:58       DAY                THEFT F/AUTO  OTHERS
# 22       1/1/17 17:18   EVENING                 THEFT/OTHER  OTHERS
# 23       1/1/17 16:38   EVENING         MOTOR VEHICLE THEFT  OTHERS
# 24       1/1/17 19:03   EVENING                 THEFT/OTHER  OTHERS
# 25       1/1/17 18:33   EVENING                THEFT F/AUTO  OTHERS
# 26       1/1/17 17:45   EVENING                THEFT F/AUTO  OTHERS
# 27       1/1/17 18:13   EVENING                 THEFT/OTHER  OTHERS
# 28       1/1/17 18:27   EVENING                THEFT F/AUTO  OTHERS
# 29       1/1/17 18:31   EVENING                 THEFT/OTHER  OTHERS
# ...               ...       ...                         ...     ...
# 33040  10/19/17 14:18       DAY                 THEFT/OTHER  OTHERS
# 33041  10/19/17 15:00       DAY                 THEFT/OTHER  OTHERS
# 33042  10/19/17 16:26   EVENING                 THEFT/OTHER  OTHERS
# 33043  10/19/17 17:38   EVENING                    BURGLARY  OTHERS
# 33044  10/19/17 17:33   EVENING                    BURGLARY  OTHERS
# 33045  10/20/17 20:30   EVENING                THEFT F/AUTO  OTHERS
# 33046  10/19/17 18:01   EVENING                    BURGLARY  OTHERS
# ...            ...
# 33040     0.050404
# 33041     0.046953
# 33042     0.104442
# 33043     0.242465
# 33044     0.242465
# 33045     0.081622
# 33046     0.005986
# 33047     0.068213
# 33048     0.073185
# 33049     0.068815
# 33050     0.082249
# 33051     0.101418
# 33052     0.020572
# 33053     0.108487
# 33054     0.101200
# 33055     0.221264
# 33056     0.069948
# 33057     0.127085
# 33058     0.143706
# 33059     0.077869
# 33060     0.055408
# 33061     0.073350
# 33062     0.143706
# 33063     0.082249
# 33064     0.097179
# 33065     0.050404
# 33066     0.079451
# 33067     0.152822
# 33068     0.050152
# 33069     0.143706
#
# [33070 rows x 41 columns]

# %% [markdown]
# Investigate 'Offense'

# %%
print(data['offense'].value_counts())
# Out:
# THEFT/OTHER                   14448
# THEFT F/AUTO                  10256
# MOTOR VEHICLE THEFT            2411
# ROBBERY                        2170
# ASSAULT W/DANGEROUS WEAPON     1851
# BURGLARY                       1525
# SEX ABUSE                       290
# HOMICIDE                        115
# ARSON                             4
# Name: offense, dtype: int64

# %%
print(data['offense'].describe())
data['offense'].mode() == "THEFT/OTHER"
# Out:
# count           33070
# unique              9
# top       THEFT/OTHER
# freq            14448
# Name: offense, dtype: object
# 0    True
# Name: offense, dtype: bool

# %%
from scipy.stats import chisquare
print(chisquare(data['offense'].value_counts()))
# Out:
# Power_divergenceResult(statistic=56821.47420622921, pvalue=0.0)

# %% [markdown]
# Split by property crime vs. violent crime

# %%
data['offense'].replace('ASSAULT W/DANGEROUS WEAPON', 'ASSAULT_WEAPON', inplace=True)
data['offense'].replace('MOTOR VEHICLE THEFT', 'VEHICLE_THEFT', inplace=True)
data['offense'].replace('SEX ABUSE', 'SEX_ABUSE', inplace=True)
data['offense'].replace('THEFT F/AUTO', 'THEFT_F_AUTO', inplace=True)
data['offense'].replace('THEFT/OTHER', 'THEFT_OTHER', inplace=True)

crimes = ['ARSON', 'ASSAULT_WEAPON', 'BURGLARY', 'HOMICIDE', 'VEHICLE_THEFT',
          'ROBBERY', 'SEX_ABUSE', 'THEFT_F_AUTO', 'THEFT_OTHER']

for crime in crimes:
    crime_flag=lambda x:1 if x==crime else 0
    data[crime] = data['offense'].map(crime_flag)
    
data.columns = map(str.lower, data.columns)
    
data['property_crime'] =  data['burglary'] + data['vehicle_theft'] + data['theft_f_auto'] + data['theft_other']
data['violent_crime'] = data['arson'] + data['assault_weapon'] + data['homicide'] + data['robbery'] + data['sex_abuse']

data['offense'] = data['offense'].astype('category')
categories = data['offense'].cat.categories
property_crimes = ['BURGLARY','VEHICLE_THEFT','THEFT_F_AUTO','THEFT_OTHER']

palette = ['b' if (x in property_crimes) else 'r' for x in categories]

import matplotlib.pyplot as plt
data['offense'].value_counts(sort=False).plot.bar(color=palette, title="Crime in Washington, DC - 2017")
plt.xlabel('Crime Type')
plt.ylabel('Count')
# Out:
# Text(0,0.5,u'Count')

# %% [markdown]
# Explore relationship between 'Offense' and 'Method'

# %%
print(data['method'].value_counts())
# Out:
# OTHERS    30666
# GUN        1583
# KNIFE       821
# Name: method, dtype: int64

# %%
pd.crosstab(data['offense'], data['method'], normalize='index', margins=True)
# Out:
# method               GUN     KNIFE    OTHERS
# offense
# ARSON           0.000000  0.000000  1.000000
# ASSAULT_WEAPON  0.368449  0.349541  0.282010
# BURGLARY        0.001967  0.000656  0.997377
# HOMICIDE        0.756522  0.078261  0.165217
# ROBBERY         0.368664  0.068664  0.562673
# SEX_ABUSE       0.037931  0.044828  0.917241
# THEFT_F_AUTO    0.000000  0.000000  1.000000
# THEFT_OTHER     0.000000  0.000138  0.999862
# VEHICLE_THEFT   0.000000  0.000000  1.000000
# All             0.047868  0.024826  0.927306

# %%
from scipy import stats
chi,p,df,expected = stats.chi2_contingency(observed=pd.crosstab(data['offense'], data['method']))
if p > 0.05:
    print('Offense type and method are independent')
else:
    print('Offense type and method are not independent')
# Out:
# Offense type and method are not independent

# %%
table=pd.crosstab(data['offense'], data['method'],normalize='index',margins=True)
import seaborn as sns
ax=sns.heatmap(table,yticklabels=True,linewidths=.5,annot=True,fmt='.2f',cmap="YlGnBu")
ax.set_title('Share of Crimes Commited by Given Method')
# Out:
# Text(0.5,1,u'Share of Crimes Commited by Given Method')

# %% [markdown]
# Explore relationship between 'Offense' and race/ethnicity charateristics of census tracts

# %%
print(pd.pivot_table(data, values='sharenhw', index='offense', aggfunc='mean', margins=True))
# Out:
#                 sharenhw
# offense
# ARSON           0.364512
# ASSAULT_WEAPON  0.182556
# BURGLARY        0.286851
# HOMICIDE        0.120979
# ROBBERY         0.256445
# SEX_ABUSE       0.276950
# THEFT_F_AUTO    0.384250
# THEFT_OTHER     0.407862
# VEHICLE_THEFT   0.254021
# All             0.359144

# %%
print(pd.pivot_table(data, values='shareblack', index='offense', aggfunc='mean', margins=True))
# Out:
#                 shareblack
# offense
# ARSON             0.483354
# ASSAULT_WEAPON    0.702312
# BURGLARY          0.573259
# HOMICIDE          0.793151
# ROBBERY           0.600372
# SEX_ABUSE         0.588118
# THEFT_F_AUTO      0.441490
# THEFT_OTHER       0.427941
# VEHICLE_THEFT     0.617108
# All               0.481871

# %%
print(pd.pivot_table(data, values='sharehisp', index='offense', aggfunc='mean', margins=True))
# Out:
#                 sharehisp
# offense
# ARSON            0.101884
# ASSAULT_WEAPON   0.073039
# BURGLARY         0.086401
# HOMICIDE         0.058967
# ROBBERY          0.090765
# SEX_ABUSE        0.078871
# THEFT_F_AUTO     0.104020
# THEFT_OTHER      0.091662
# VEHICLE_THEFT    0.080129
# All              0.093090

# %% [markdown]
# On average, crimes occured in census tracts that were 36% non-Hispanic white, 48% African American, and 9% Hispanic.
# Homicides on average occured in census tracts that were 12% non-Hispanic white, 79% African American, and 6% Hispanic.

# %%
from matplotlib import pyplot

for race in 'sharenhw', 'shareblack', 'sharehisp':
    mydims = (13,8)
    fig, ax = pyplot.subplots(figsize=mydims)
    sns.boxplot(x='offense', y=race, data=data, ax=ax)

# %% [markdown]
# Aggregate the data by census tract

# %%
for i in range(0,len(crimes)):
    crimes[i] = crimes[i].lower()

print(crimes)
crimes.append('violent_crime')
crimes.append('property_crime')
vars = crimes[:]
vars.append('tract')
tractlevel_totalcrime = data[vars]
data_tract = tractlevel_totalcrime.groupby('tract').sum().reset_index()

covars = ['tract','sharenhw','shareblack','sharehisp','hh_med_income','unemp_rate','vacancy_rate']
data_covars = data[covars]
data_covars = data_covars.groupby('tract').first().reset_index()
  
data_tractlevel = pd.merge(data_tract, data_covars, left_index=True, right_index=True, validate='1:1', indicator=True, how='left')
data_tractlevel['_merge'].value_counts()
del data_tractlevel['_merge']

del data_tractlevel['tract_y']
data_tractlevel.rename(index=str, columns={'tract_x':'tract'}, inplace=True)
display(data_tractlevel)
# Out:
# ['arson', 'assault_weapon', 'burglary', 'homicide', 'vehicle_theft', 'robbery', 'sex_abuse', 'theft_f_auto', 'theft_other']
#        tract  arson  assault_weapon  burglary  homicide  vehicle_theft  \
# 0      100.0      0               0        15         0             19
# 1      201.0      0               1         0         0              1
# 2      202.0      0              12        18         1             16
# 3      300.0      0               5        11         0              5
# 4      400.0      0               0         0         0              5
# 5      501.0      0               3         2         0              3
# 6      502.0      0               1         7         0              2
# 7      600.0      0               3        10         0              3
# 8      701.0      0               1         3         0              4
# 9      702.0      0               0         0         0              0
# 10     801.0      0               0         3         0             10
# 11     802.0      0               0         3         0              4
# 12     901.0      0               0         8         0             15
# 13     902.0      0               0         4         0              2
# 14    1001.0      0               2        26         0              8
# 15    1002.0      0               3         0         0              5
# 16    1100.0      0               3         9         0              5
# 17    1200.0      0               3        10         0              8
# 18    1301.0      0               0         0         0              4
# 19    1302.0      0               1         0         0              1
# 20    1401.0      0               0         2         0              6
# 21    1402.0      0               0         3         0              5
# 22    1500.0      0               0         2         0             18
# 23    1600.0      0               3         3         0             11
# 24    1702.0      0               2         2         0              5
# 25    1803.0      0               2         5         0              8
# 26    1804.0      0              10         4         1             12
# 27    1901.0      0               3         4         1              5
# 28    1902.0      0               3         2         1              6
# 29    2001.0      0               0         1         0              5
# ..       ...    ...             ...       ...       ...            ...
# 149   9601.0      0              21         7         2             18
# 150   9602.0      0              15         1         0             30
# 151   9603.0      0              43        11         1             34
# 152   9604.0      0              23         0         1             20
# 153   9700.0      1              17         4         1             18
# 154   9801.0      0               7         6         1             13
# 155   9802.0      0              10         5         0              5
# 156   9803.0      0              13         6         2             15
# 157   9804.0      0               8        28         2              7
# 158   9807.0      0              23        17         5             15
# 159   9810.0      0              19         8         0              5
# 160   9811.0      0              29        10         1             13
# 161   9901.0      0               4         4         0              5
# 162   9902.0      0               5         7         0             15
# 163   9903.0      0              10         4         0             15
# 164   9904.0      0              14         8         0             24
# 165   9905.0      0              18         6         0             24
# 166   9906.0      0               4         7         0             13
# 167   9907.0      0              13         1         1             26
# 168  10100.0      0              13         6         0             16
# 169  10200.0      0               4         4         0             19
# 170  10300.0      0               1         4         1             10
# 171  10400.0      0              30        39         2             23
# 172  10500.0      0               6         1         0              5
# 173  10600.0      0              20        27         0             22
# 174  10700.0      0              31        33         0             25
# 175  10800.0      0               2         4         0              4
# 176  10900.0      0              23        16         2             14
# 157       0.261      0.073975
# 158       0.208      0.235077
# 159       0.306      0.019818
# 160       0.302      0.140603
# 161       0.109      0.095964
# 162       0.141      0.178545
# 163       0.068      0.093668
# 164       0.149      0.219345
# 165       0.276      0.201299
# 166       0.153      0.141772
# 167       0.236      0.075099
# 168       0.053      0.096774
# 169       0.058      0.129116
# 170       0.132      0.072344
# 171       0.241      0.144044
# 172       0.087      0.040913
# 173       0.044      0.102742
# 174       0.035      0.127085
# 175       0.090      0.155393
# 176       0.261      0.107387
# 177       0.028      0.079909
# 178       0.163      0.101200
#
# [179 rows x 18 columns]

# %% [markdown]
# Violent crime by tract

# %%
print(data_tractlevel['violent_crime'].describe())
data_tractlevel['violent_crime'].plot(kind='hist',bins=30,figsize=(10,8))
# Out:
# count    179.000000
# mean      24.636872
# std       19.927593
# min        0.000000
# 25%       10.000000
# 50%       20.000000
# 75%       32.500000
# max      105.000000
# Name: violent_crime, dtype: float64

# %%
plot,outliers=data_tractlevel['violent_crime'].plot.box(vert=False,return_type='both')

# %% [markdown]
# Investigate census tracts with high amounts of violent crime

# %%
len([flier.get_xdata() for flier in outliers["fliers"]][0])
[flier.get_xdata() for flier in outliers["fliers"]][0]
caps = [value.get_xdata()[0] for value in outliers["caps"]] 
lower_bound = caps[0]
upper_bound = caps[1]

outliers_vc = lambda x: 1 if (x<lower_bound) else 2 if (x>upper_bound) else np.nan if pd.isnull(x) else 0
data_tractlevel['out_vc'] = data_tractlevel['violent_crime'].map(outliers_vc)


N = len(data_tractlevel)
index = list(range(0,N,1))

print('tract', 'sharenhw', 'shareblack', 'sharehisp', 'hh_med_income', 'unemp_rate', 'vacancy_rate')
for i in index:
    if (data_tractlevel.out_vc[i]==2):
        print(data_tractlevel.tract[i],
              round(data_tractlevel.sharenhw[i],3),
              round(data_tractlevel.shareblack[i],3),
              round(data_tractlevel.sharehisp[i],3),
              data_tractlevel.hh_med_income[i],
              round(data_tractlevel.unemp_rate[i],3),
              round(data_tractlevel.vacancy_rate[i],3))
# Out:
# ('tract', 'sharenhw', 'shareblack', 'sharehisp', 'hh_med_income', 'unemp_rate', 'vacancy_rate')
# (4400.0, 0.677, 0.161, 0.056, 154402.0, 0.04, 0.028)
# (7601.0, 0.06, 0.905, 0.025, 34107.0, 0.165, 0.147)
# (7803.0, 0.016, 0.875, 0.091, 37234.0, 0.169, 0.119)
# (7804.0, 0.002, 0.932, 0.049, 45396.0, 0.147, 0.157)
# (7808.0, 0.003, 0.946, 0.044, 32376.0, 0.266, 0.176)
# (8803.0, 0.233, 0.616, 0.09, 17303.0, 0.188, 0.172)
# (9603.0, 0.003, 0.959, 0.027, 40551.0, 0.194, 0.106)
# (10400.0, 0.048, 0.917, 0.029, 38750.0, 0.241, 0.144)
# (11100.0, 0.08, 0.841, 0.03, 59716.0, 0.163, 0.101)

# %%
table_outvc=pd.crosstab(data_tractlevel['tract'],data_tractlevel['out_vc'])

print(data_tractlevel['out_vc'].value_counts())
table_outvc.columns = ['normal', 'high_vc']
table_outvc.replace(0, np.nan,inplace=True)
high_vc = set(table_outvc["high_vc"].dropna().index)
high_vc
# Out:
# 0    170
# 2      9
# Name: out_vc, dtype: int64
# {4400.0, 7601.0, 7803.0, 7804.0, 7808.0, 8803.0, 9603.0, 10400.0, 11100.0}

# %% [markdown]
# Property crime by tract

# %%
print(data_tractlevel['property_crime'].describe())
data_tractlevel['property_crime'].plot(kind='hist',bins=30,figsize=(10,8))
# Out:
# count    179.000000
# mean     159.648045
# std      138.016096
# min        2.000000
# 25%       78.000000
# 50%      116.000000
# 75%      179.500000
# max      995.000000
# Name: property_crime, dtype: float64

# %% [markdown]
# Investigate census tracts with high amounts of property crime

# %%
plot,outliers=data_tractlevel['property_crime'].plot.box(vert=False,return_type='both')

# %%
len([flier.get_xdata() for flier in outliers["fliers"]][0])
[flier.get_xdata() for flier in outliers["fliers"]][0]
caps = [value.get_xdata()[0] for value in outliers["caps"]] 
lower_bound = caps[0]
upper_bound = caps[1]

outliers_pc = lambda x: 1 if (x<lower_bound) else 2 if (x>upper_bound) else np.nan if pd.isnull(x) else 0
data_tractlevel['out_pc'] = data_tractlevel['property_crime'].map(outliers_pc)

print('tract', 'sharenhw', 'shareblack', 'sharehisp', 'hh_med_income', 'unemp_rate', 'vacancy_rate')
for i in index:
    if (data_tractlevel.out_pc[i]==2):
        print(data_tractlevel.tract[i],
              round(data_tractlevel.sharenhw[i],3),
              round(data_tractlevel.shareblack[i],3),
              round(data_tractlevel.sharehisp[i],3),
              data_tractlevel.hh_med_income[i],
              round(data_tractlevel.unemp_rate[i],3),
              round(data_tractlevel.vacancy_rate[i],3))
# Out:
# ('tract', 'sharenhw', 'shareblack', 'sharehisp', 'hh_med_income', 'unemp_rate', 'vacancy_rate')
# (100.0, 0.839, 0.011, 0.094, 167188.0, 0.042, 0.166)
# (202.0, 0.773, 0.077, 0.065, 161378.0, 0.047, 0.144)
# (3000.0, 0.41, 0.458, 0.094, 77609.0, 0.091, 0.097)
# (3100.0, 0.324, 0.272, 0.286, 84278.0, 0.048, 0.081)
# (3500.0, 0.178, 0.723, 0.027, 77500.0, 0.089, 0.02)
# (4400.0, 0.677, 0.161, 0.056, 154402.0, 0.04, 0.028)
# (4702.0, 0.485, 0.374, 0.072, 100179.0, 0.047, 0.048)
# (5201.0, 0.72, 0.043, 0.123, 109074.0, 0.025, 0.11)
# (5500.0, 0.731, 0.058, 0.087, 77808.0, 0.024, 0.108)
# (5800.0, 0.627, 0.068, 0.074, 135718.0, 0.089, 0.255)
# (9102.0, 0.094, 0.838, 0.037, 42054.0, 0.144, 0.055)
# (9603.0, 0.003, 0.959, 0.027, 40551.0, 0.194, 0.106)
# (10100.0, 0.578, 0.147, 0.107, 87037.0, 0.053, 0.097)
# (10600.0, 0.615, 0.247, 0.053, 108571.0, 0.044, 0.103)
# (10700.0, 0.775, 0.048, 0.083, 72731.0, 0.035, 0.127)
# (11100.0, 0.08, 0.841, 0.03, 59716.0, 0.163, 0.101)

# %%
print(data_tractlevel['out_pc'].value_counts())
table_outpc=pd.crosstab(data_tractlevel['tract'],data_tractlevel['out_pc'])

table_outpc.columns = ['normal', 'high_pc']
table_outpc.replace(0, np.nan,inplace=True)
table_outpc
high_pc = set(table_outpc["high_pc"].dropna().index)
high_pc
# Out:
# 0    163
# 2     16
# Name: out_pc, dtype: int64
# {100.0,
#  202.0,
#  3000.0,
#  3100.0,
#  3500.0,
#  4400.0,
#  4702.0,
#  5201.0,
#  5500.0,
#  5800.0,
#  9102.0,
#  9603.0,
#  10100.0,
#  10600.0,
#  10700.0,
#  11100.0}

# %% [markdown]
# Tracts that are outliers in both violent and property crime

# %%
high_vc & high_pc
# Out:
# {4400.0, 9603.0, 11100.0}

# %% [markdown]
# How do outlier census tracts in violent crime compare to outlier tracts in property crime?

# %%
for var in 'sharenhw', 'shareblack', 'sharehisp', 'hh_med_income', 'unemp_rate', 'vacancy_rate':
    print('************************')
    for type in 'out_pc', 'out_vc':
        print(pd.pivot_table(data_tractlevel, values=var, index=type, aggfunc='mean'))
# Out:
# ************************
#         sharenhw
# out_pc
# 0       0.323483
# 2       0.494335
#         sharenhw
# out_vc
# 0       0.350091
# 2       0.124631
# ************************
#         shareblack
# out_pc
# 0         0.522876
# 2         0.332880
#         shareblack
# out_vc
# 0         0.490604
# 2         0.794685
# ************************
#         sharehisp
# out_pc
# 0        0.097223
# 2        0.082042
#         sharehisp
# out_vc
# 0        0.098350
# 2        0.048954
# ************************
#         hh_med_income
# out_pc
# 0         76471.84375
# 2         97237.12500
#         hh_med_income
# out_vc
# 0        79829.065868
# 2        51092.777778
# ************************
#         unemp_rate
# out_pc
# 0         0.108859
# 2         0.073438
#         unemp_rate
# out_vc
# 0         0.102035
# 2         0.174778
# ************************
#         vacancy_rate
# out_pc
# 0           0.099140
# 2           0.102852
#         vacancy_rate
# out_vc
# 0           0.097968
# 2           0.127869

# %% [markdown]
# Scatterplots for all tracts

# %%
for crime in 'violent_crime', 'property_crime':
    cols=[crime, 'sharenhw', 'shareblack', 'sharehisp', 'hh_med_income', 'unemp_rate', 'vacancy_rate']
    forgraph = pd.DataFrame(data_tractlevel, columns=cols)
    sns.pairplot(forgraph.dropna())

# %%
for crime in 'violent_crime', 'property_crime':
    cols=[crime, 'sharenhw', 'shareblack', 'sharehisp', 'hh_med_income', 'unemp_rate', 'vacancy_rate']
    forcorr = pd.DataFrame(data_tractlevel, columns=cols)
    print(forcorr.corr())
    print('*************************************************************************************')
    print('Spearman')
    print(forcorr.corr(method='spearman'))
    print('*************************************************************************************')
# Out:
#                violent_crime  sharenhw  shareblack  sharehisp  hh_med_income  \
# violent_crime       1.000000 -0.486868    0.506554  -0.208210      -0.475790
# sharenhw           -0.486868  1.000000   -0.959538   0.109177       0.791386
# shareblack          0.506554 -0.959538    1.000000  -0.369351      -0.767535
# sharehisp          -0.208210  0.109177   -0.369351   1.000000       0.141167
# hh_med_income      -0.475790  0.791386   -0.767535   0.141167       1.000000
# unemp_rate          0.443660 -0.744067    0.798027  -0.381676      -0.690437
# vacancy_rate        0.303802 -0.280219    0.316634  -0.260173      -0.310850
#
#                unemp_rate  vacancy_rate
# violent_crime    0.443660      0.303802
# sharenhw        -0.744067     -0.280219
# shareblack       0.798027      0.316634
# sharehisp       -0.381676     -0.260173
# hh_med_income   -0.690437     -0.310850
# unemp_rate       1.000000      0.286790
# vacancy_rate     0.286790      1.000000
# *************************************************************************************
# Spearman
#                violent_crime  sharenhw  shareblack  sharehisp  hh_med_income  \
# violent_crime       1.000000 -0.586606    0.582356  -0.329522      -0.584239
# sharenhw           -0.586606  1.000000   -0.963089   0.378856       0.840685
# shareblack          0.582356 -0.963089    1.000000  -0.540704      -0.811215
# sharehisp          -0.329522  0.378856   -0.540704   1.000000       0.382480
# hh_med_income      -0.584239  0.840685   -0.811215   0.382480       1.000000
# unemp_rate          0.566623 -0.860966    0.871665  -0.454628      -0.792364
# vacancy_rate        0.349429 -0.309637    0.322695  -0.251249      -0.342536
#
#                unemp_rate  vacancy_rate
# violent_crime    0.566623      0.349429
# sharenhw        -0.860966     -0.309637
# shareblack       0.871665      0.322695
# sharehisp       -0.454628     -0.251249
# hh_med_income   -0.792364     -0.342536
# unemp_rate       1.000000      0.333829
# vacancy_rate     0.333829      1.000000
# *************************************************************************************
#                 property_crime  sharenhw  shareblack  sharehisp  \
# property_crime        1.000000  0.163339   -0.166259  -0.014212
# sharenhw              0.163339  1.000000   -0.959538   0.109177
# shareblack           -0.166259 -0.959538    1.000000  -0.369351
# sharehisp            -0.014212  0.109177   -0.369351   1.000000
# hh_med_income         0.133310  0.791386   -0.767535   0.141167
# unemp_rate           -0.145419 -0.744067    0.798027  -0.381676
# vacancy_rate          0.074084 -0.280219    0.316634  -0.260173
#
#                 hh_med_income  unemp_rate  vacancy_rate
# property_crime       0.133310   -0.145419      0.074084
# sharenhw             0.791386   -0.744067     -0.280219
# shareblack          -0.767535    0.798027      0.316634
# sharehisp            0.141167   -0.381676     -0.260173
# hh_med_income        1.000000   -0.690437     -0.310850
# unemp_rate          -0.690437    1.000000      0.286790
# vacancy_rate        -0.310850    0.286790      1.000000
# *************************************************************************************
# Spearman
#                 property_crime  sharenhw  shareblack  sharehisp  \
# property_crime        1.000000  0.105228   -0.095672   0.017592
# sharenhw              0.105228  1.000000   -0.963089   0.378856
# shareblack           -0.095672 -0.963089    1.000000  -0.540704
# sharehisp             0.017592  0.378856   -0.540704   1.000000
# hh_med_income         0.073286  0.840685   -0.811215   0.382480
# unemp_rate           -0.066575 -0.860966    0.871665  -0.454628
# vacancy_rate          0.076783 -0.309637    0.322695  -0.251249
#
#                 hh_med_income  unemp_rate  vacancy_rate
# property_crime       0.073286   -0.066575      0.076783
# sharenhw             0.840685   -0.860966     -0.309637
# shareblack          -0.811215    0.871665      0.322695
# sharehisp            0.382480   -0.454628     -0.251249
# hh_med_income        1.000000   -0.792364     -0.342536
# unemp_rate          -0.792364    1.000000      0.333829
# vacancy_rate        -0.342536    0.333829      1.000000
# *************************************************************************************

# %% [markdown]
# Violent crime is more strongly correlated with census tract demographics and household income, the unemployment rate, and vacancy rate than property crime
